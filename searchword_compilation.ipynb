# %%
import pandas as pd

# %%
sw_partial_df = pd.read_csv('search_words_partial.csv',header=None)

# %%
sw_partial_df
# Out:
#                                                      0
# 0                                             Hospital
# 1                                               Mosque
# 2                                               School
# 3                                               Clinic
# 4                                              Nursery
# 5                                                House
# 6                                                 Home
# 7                                              Charity
# 8                                           Charitable
# 9                                          Real Estate
# 10                                     First-aid posts
# 11                                      Dental Centres
# 12                                      Dental Centers
# 13                                     Medical Centres
# 14                                     Medical Centers
# 15                             General Medical Centres
# ...

# %%
schools_df = pd.read_csv('schools_lebanon.csv',header=None)

# %%
schools_df
# Out:
#                                                 0
# 0                   College de la Sagesse St Elie
# 1                     College La Sagesse St Maron
# 2              A & C Haydakos High School College
# 3                                   Ahliah school
# 4                                              Al
# 5                      American Academy of Beirut
# 6        Armenian Evangelical Central High School
# 7         Armenian Evangelical Guertmenian School
# 8             American Community School at Beirut
# 9                           Beirut Baptist School
# 10   Beirut Evangelical School for Girls and Boys
# 11                           Beirut Modern School
# 12                   College La Sagesse St Joseph
# 13                         Collège Louise Wegmann
# 14                 Collège Notre Dame de Nazareth
# 15                                  Collège Saint
# 16     Collège Saint François Des Peres Capucinns
# 17                       Ecole des Trois Docteurs
# ...

# %%
search_words.to_csv("terms_english.csv",sep=',',index = False, header = False)

# %%
cities_df = pd.read_csv('cities_lebanon.csv',header=None)
cities_df.drop_duplicates(inplace = True, subset = 0)
for city in cities_df[0]:
    print(city)
# Out:
# Abey
# Aghmid
# Ain Dara
# Ain el Remmaneh
# Ain el Saydeh
# Ain Jedideh
# Ain Ksour
# Ain Onoub
# Ainab
# Aley
# Aramoun el Ghareb
# Baawerta
# Badghan
# Baissour
# Bassatine
# Bchamoun
# Bdadoun
# Bemkine
# Bennieh
# Bhamdoun el Balda
# Bhamdoun el Mhatta
# Bkhechtey
# Bleibel
# Bmahray
# Bserrine
# Bsouss
# Btalloun
# Btater
# Chanay
# Charoun
# Chartoun
# Chemlan
# Choueifat
# Deir Koubel
# Dfoun
# Eitat
# Houmal
# Kehaleh
# Keyfoun
# Kfaraamey
# Kfarmatta
# Kommatyeh
# Majdelbaana
# Mansourieh
# Mecherfeh
# Mejdlaya
# Rajmeh
# Ramlieh
# Ras el Jabal
# Rechmaya
# Remhala
# Rouaysset el Neeman
# Saoufar
# Souk el Ghareb
# Taazanieh
# Achqout
# Adonis
# Ain el Rihaneh
# Aintoura
# Ajaltoun
# Akaybeh
# Aramoun
# Azra
# Ballouneh
# Batha
# Bekaatat Achkout
# Bouar
# Bezhel
# Bqaatouta
# Chahtoul
# Chnaniir
# Daraya
# Daraoun
# Dlebta
# Faitroun
# Faraya
# Fatka
# Ghazir
# Ghbaleh
# Ghedrass
# Ghosta
# Ghyneh
# Hiyata
# Hosein
# Hrajel
# Jdeideh
# Jeita
# Jounieh
# Jouret Termos
# ...

# %%
search_words = sw_partial_df.append(schools_df)

# %%
search_words = search_words.append(cities_df)
search_words
# Out:
#                            0
# 0                   Hospital
# 1                     Mosque
# 2                     School
# 3                     Clinic
# 4                    Nursery
# 5                      House
# 6                       Home
# 7                    Charity
# 8                 Charitable
# 9                Real Estate
# 10           First-aid posts
# 11            Dental Centres
# 12            Dental Centers
# 13           Medical Centres
# 14           Medical Centers
# 15   General Medical Centres
# 16                Bayt Jbail
# 17                Beit Jbail
# 18                Bent Jbail
# 19               Development
# 20            Reconstruction
# 21            Infrastructure
# 22                  Donation
# 23   Reconstruction Campaign
# 24                   Station
# 25             Train Station
# 26                   Airport
# 27              Construction
# 28            Social Service
# 29                    Donate
# ..                       ...
# ...
