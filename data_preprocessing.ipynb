# %%
import pandas as pd
import csv
import re
import numpy as np

# %%
df_english = pd.read_csv("sample_output.csv")
df_english.drop_duplicates(inplace= True, subset = "sentence")
df_english.to_csv('hezbollah_output.csv',index=False)

# %%
search_words = []
search_words = pd.read_csv('C:/Users/Alex/Desktop/HezbollahScrapper/terms_english.csv',encoding='utf-8',header=None)
search_words[0] = search_words[0].astype(str).apply(lambda x: x.lower())

# %%
def matcher(x):
    for i in search_words[0]:
        if i.lower() in x.lower() and i != 'al': 
            return i
    else:
        return np.nan
df_english['word'] = df_english['sentence'].apply(matcher)

# %%
df_english_filtered = df_english.dropna(subset=["word"])
df_english_filtered.to_csv("english_output_4-13.csv",index=False)

# %%
    with open('C:/Users/Alex/Desktop/HezbollahScrapper/terms_arabic.csv','r',encoding='utf-8') as csvfile:
        terms_reader = csv.reader(csvfile,delimiter = ',')
        for row in terms_reader:
            print(row)
# Out:
# ['مستشفى']
# ['مستشفيات']
# ['مسجد']
# ['مساجد']
# ['مدرسة']
# ['مدارس']
# ['عيادة']
# ['عيادات']
# ['حضانة']
# ['حضانات']
# ['منزل']
# ['منازل']
# ['بيت']
# ['بيوت']
# ['دار']
# ['ديار']
# ['مسكن']
# ['مساكن']
# ['الاعمال الخيرية']
# ['خيري']
# ['خيرية']
# ['العقارات']
# ['وظائف الإسعافات الأولية']
# ['مركز الأسنان']
# ['مراكز الأسنان']
# ['مركز الطبية']
# ['المراكز الطبية']
# ['مركز الطبية العامة']
# ['المراكز الطبية العامة']
# ['بيت جبيل']
# ['بنت جبيل']
# ['جهاد البناء']
# ['جمعية جهاد البناء']
# ['تطوير']
# ['إعادة الإعمار']
# ['بنية تحتية']
# ['هبة']
# ['إمداد']
# ['جمعيّة الإمداد الخيريّة الإسلاميّة']
# ['جمعيّة الإمداد']
# ['حملة إعادة الإعمار']

# %%
csv_df = pd.read_csv("english_output_cleaned.csv",delimiter=",")
csv_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-114-f2237c3b9c5a> in <module>()
# ----> 1 csv_df = pd.read_csv("english_output_cleaned.csv",delimiter=",")
#       2 csv_df
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
df2 = pd.DataFrame()
for indx, row in csv.iterrows():
    m = re.search('(\$[0-9]+)((\.|\,)[0-9]+)?',row["sentence"])
    if(m):
        money = pd.Series(m.group(),index=["money"])
        series = pd.concat([csv.iloc[indx],money])
        series.name = indx
        df2 =df2.append(series)

# %%
df2
# Out:
#          money                                           sentence  \
# 7     $100,000  While Hezbollah promotes itself as a guardian ...
# 46          $1  Beyond rhetoric, the Iranian government has co...
# 82         $15  “Hezbollah leader Hassan Nasrallah condemned n...
# 112       $100  “The funding of the Lebanese Hezbollah organiz...
# 133       $200  “International investigations are revealing th...
# 151       $300   Hezbollah claimed it spent $300 million for i...
# 187         $1  Hezbollah chief Hassan Nasrallah on Friday sai...
# 190         $3  Last December, Saudi Arabia agreed to finance ...
# 259         $1  One, consisting of 203 pages, was filed on Jan...
# 305   $700,000  BEIRUT: The American University of Beirut, a r...
# 502         $1  \r\r\n\tIn 2010, Treasury also designated Taji...
# 554       $700   Representatives from Hezbollah’s Al-Nour radi...
# 561       $600  \r\r\n\tFlush with revenues from skyrocketing ...
# ...

# %%
city_list = []
df3 = pd.DataFrame()

with open('cities_lebanon.csv','r') as csvfile:
    cities_reader = csv.reader(csvfile,delimiter = ',')    
    for cities in cities_reader:
        for city in cities:
            city_list.append(city)
            
city_list.remove('Al')  
city_list.remove('As') 
for indx, row in csv_df.iterrows():
    for city in city_list:
        if city in row["sentence"]:
            city_series = pd.Series(city,index=["city"])
            series = pd.concat([csv_df.iloc[indx],city_series])
            series.name = indx
            df3 =df3.append(series)

# %%
df3
# Out:
#              city                                           sentence  \
# 36          Ansar   specifically mentioned the Al Rawdah mosque a...
# 40           Abra  Khomeini’s Islamist, populist agenda—dubbed “K...
# 47            Ram  The Iranian government continues to inculcate ...
# 85       Khartoum  “The process of removing Sudan from the U.S. l...
# 111           Ram  “The Israeli military on Thursday called on a ...
# 153       Baalbek   The banks also targeted Baalbek Hospital, Wes...
# 185       Baalbek  Hezbollah's Loyalty to Development candidate l...
# 201           Ram  Khomeini’s early support for Hezbollah was but...
# 231       Baalbek  Israeli commandos in helicopters raid an Irani...
# 244       Baalbek  The LCP group boasts dozens of volunteers who ...
# 244   Ras Baalbek  The LCP group boasts dozens of volunteers who ...
# 267    Bint Jbeil  An anti-Hezbollah parliamentary candidate in s...
# 268         Arsal  Hezbollah fighters made major gains over the w...
# ...

# %%
df2.to_csv("english_output_money.csv",index=False)
df3.to_csv("english_output_cities.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-8760f6a8d171> in <module>()
# ----> 1 df2.to_csv("english_output_money.csv",index=False)
#       2 df3.to_csv("english_output_cities.csv",index=False)
#
# NameError: name 'df2' is not defined

# %%
csv_arabic = pd.read_csv("arabic_output.csv",delimiter=",")

# %%
csv_arabic.drop_duplicates(subset = "sentence",inplace = True)

# %%
csv_arabic.to_csv("arabic_output_cleaned.csv",index = False)

# %%
csv_arabic
# Out:
#                                                sentence  \
# 0     في المبدأ، استُحدث «اختصاص المرور» بدافع الحاج...
# 1     زعامة عون لم تقم على أساس استقطاب حزب الجيش وج...
# 2     ومتوجهاً إلى قوى 14 آذار الحاضرين بممثليهم في ...
# 3     الامر الثالث المتعلق بحزب الله هو المتصل بالرب...
# 4     لم يُلقَ العريس كلمة عن الحب، والحياة الزوجية،...
# 7     ويبدي كرامي تخوفه من المرحلة المقبلة و«خصوصاً ...
# 8     وخلص التقرير إلى أنه تم إنفاق 1.6 مليون دولار ...
# 9     منذ خلوة بيت شباب ثم خلوة مار الياس في الكنيسة...
# 10    يقول معنيون بالمجريات الانتخابية لهذه الدائرة ...
# 13    الأكثر مدعاة للاستغراب، أن السعودية الموسومة ب...
# 14    مشقة الزعامة التي يكابد الحريري لنيلها لم تعد ...
# 15    بحسب مصادر ماكينتي مراد وحركة أمل، كان تيار ال...
# 16    أكثر ما يثير اهتمام الإعلام السعودي هذه الأيام...
# 17    وحول اتهامات عضو المجلس المركزي في حزب الله، ا...
# 18    . على فطرتها، سألت المرأة فريق العمل: «ليه ما ...
# 19    ويلزم القانون الإدارة بتقديم تقرير علني يوضح أ...
# ...

# %%
from googletrans import Translator

# %%
translator = Translator()
csv_arabic
# Out:
#                                                sentence  \
# 0     في المبدأ، استُحدث «اختصاص المرور» بدافع الحاج...
# 1     زعامة عون لم تقم على أساس استقطاب حزب الجيش وج...
# 2     ومتوجهاً إلى قوى 14 آذار الحاضرين بممثليهم في ...
# 3     الامر الثالث المتعلق بحزب الله هو المتصل بالرب...
# 4     لم يُلقَ العريس كلمة عن الحب، والحياة الزوجية،...
# 7     ويبدي كرامي تخوفه من المرحلة المقبلة و«خصوصاً ...
# 8     وخلص التقرير إلى أنه تم إنفاق 1.6 مليون دولار ...
# 9     منذ خلوة بيت شباب ثم خلوة مار الياس في الكنيسة...
# 10    يقول معنيون بالمجريات الانتخابية لهذه الدائرة ...
# 13    الأكثر مدعاة للاستغراب، أن السعودية الموسومة ب...
# 14    مشقة الزعامة التي يكابد الحريري لنيلها لم تعد ...
# 15    بحسب مصادر ماكينتي مراد وحركة أمل، كان تيار ال...
# 16    أكثر ما يثير اهتمام الإعلام السعودي هذه الأيام...
# 17    وحول اتهامات عضو المجلس المركزي في حزب الله، ا...
# 18    . على فطرتها، سألت المرأة فريق العمل: «ليه ما ...
# 19    ويلزم القانون الإدارة بتقديم تقرير علني يوضح أ...
# ...

# %%
translator = Translator()
csv_arabic_trans= csv_arabic['sentence'][1:100].apply(translator.translate, src='ar', dest='en').apply(getattr, args=('text',))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-25-461b9c1cd381> in <module>()
#       1 translator = Translator()
# ----> 2 csv_arabic_trans= csv_arabic['sentence'][1:100].apply(translator.translate, src='ar', dest='en').apply(getattr, args=('text',))
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3190             else:
#    3191                 values = self.astype(object).values
# -> 3192                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3193
#    3194         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src\inference.pyx in pandas._libs.lib.map_infer()
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in <lambda>(x)
#    3177         # handle ufuncs and lambdas
#    3178         if kwds or args and not isinstance(func, np.ufunc):
# ...

# %%
csv_arabic_test = csv_arabic[0:10]

# %%
import copy
from googletrans import Translator

translatedList = []
for index, row in csv_arabic.iterrows():
    # REINITIALIZE THE API
    translator = Translator()
    newrow = copy.deepcopy(row)
    try:
        # translate the 'text' column
        translated = translator.translate(row['sentence'], dest='en')
        newrow['sentence'] = translated.text
    except Exception as e:
        print(str(e))
        continue
    translatedList.append(newrow)
# Out:
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# Expecting value: line 1 column 1 (char 0)
# ...

# %%
pd.DataFrame(translatedList)
# Out:
#                                               sentence  \
# 0    In principle, the "traffic jurisdiction" was c...
# 1    Aoun's leadership was not based solely on attr...
# 2    "Raise your hands on the relative law and the ...
# 3    The third thing related to Hezbollah is relate...
# 4    The groom did not receive a word about love, m...
# 7    Karami is worried about the next phase, and "e...
# 8    The report concluded that $ 1.6 million had be...
# 9    Since the absence of a youth hostel and the ab...
# 10   Those involved in the electoral process of thi...
# 13   Surprisingly, Saudi Arabia, tagged with the po...
# 14   The hardships of the leadership that Hariri is...
# 15   According to the sources of Makati Murad and A...
# 16   The most important thing for the Saudi media t...
# 17   On the charges of a member of the Central Coun...
# 18   . On her instinct, the woman asked the team: "...
# 19   The law requires the administration to provide...
# ...

# %%
arabic_words_df = pd.read_csv("arabic_words_trans.csv",names= ["arab","eng"])

# %%
 = {}
with open('arabic_words_trans.csv', mode='r',encoding='utf-8') as infile:
    reader = csv.reader(infile)
    arabic_terms_trans = {row[0]:row[1] for row in reader}

# %%
arabic_terms_trans
# Out:
# {'مستشفى': 'Hospital',
#  'مستشفيات': 'Hospitals',
#  'مسجد': 'Mosque',
#  'مساجد': 'Mosques',
#  'مدرسة': 'School',
#  'مدارس': 'Schools',
#  'عيادة': 'Clinic',
#  'عيادات': 'Clinics',
#  'حضانة': 'Nursery',
#  'حضانات': 'Nurseries',
#  'منزل': 'House',
#  'منازل': 'Houses',
#  'بيت': 'House',
#  'بيوت': 'Houses',
#  'مسكن': 'Residence',
#  'مساكن': 'Residences',
#  'الاعمال الخيرية': 'Charity',
#  'خيري': 'Charitable',
#  'خيرية': 'Charitable (f.)',
#  'العقارات': 'Real Estate',
#  'وظائف الإسعافات الأولية': 'First-aid posts',
#  'مركز الأسنان': 'Dental Center',
#  'مراكز الأسنان': 'Dental Centers',
#  'مركز الطبية': 'Medical Center',
#  'المراكز الطبية': 'Medical Centers',
#  'مركز الطبية العامة': 'General Medical Centrer',
#  'المراكز الطبية العامة': 'General Medical Centres',
#  'تطوير': 'Development',
#  'إعادة الإعمار': 'Reconstruction',
#  'بنية تحتية': 'Infrastructure',
#  'هبة': 'Donation',
#  'حملة إعادة الإعمار': 'Reconstruction Campaign',
# ...

# %%
def translate_word(x):
    if x in arabic_terms_trans:
        return arabic_terms_trans[x]
    else:
        return x

# %%
csv_arabic["word"] = csv_arabic["word"].apply(lambda x:translate_word(x))

# %%
csv_arabic.to_csv("arabic_output_wordtrans_4-29.csv",index=False)
